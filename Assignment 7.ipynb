# %% [markdown]
# ## <b><center> Session 7: Assignment

# %% [markdown]
# <b> Task 1:
#
# Read the following data set:
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
#
# Rename the columns as per the description from this file:
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names

# %%
import numpy as np
import pandas as pd
import sqlite3
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
adult_data = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
adult = pd.read_csv(adult_data, header=None)
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %% [markdown]
# <b> Task:
#
#  Create a sql db from adult dataset and name it sqladb

# %%
sqladb = pd.read_csv(adult_data , engine='python',sep=r'\s*,\s*')
sqladb.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
    'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain',
    'capital-loss', 'hours-per-week', 'native-country', 'income']
sqladb.columns = sqladb.columns.str.replace("-","_")
sqladb.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   50  Self-emp-not-inc   83311  Bachelors             13
# 1   38           Private  215646    HS-grad              9
# 2   53           Private  234721       11th              7
# 3   28           Private  338409  Bachelors             13
# 4   37           Private  284582    Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# ...

# %% [markdown]
# <b> 1. Select 10 records from the adult sqladb

# %%
pysqldf("select * from sqladb limit 10")
# Out:
#    age         workclass  fnlwgt     education  education_num  \
# 0   50  Self-emp-not-inc   83311     Bachelors             13
# 1   38           Private  215646       HS-grad              9
# 2   53           Private  234721          11th              7
# 3   28           Private  338409     Bachelors             13
# 4   37           Private  284582       Masters             14
# 5   49           Private  160187           9th              5
# 6   52  Self-emp-not-inc  209642       HS-grad              9
# 7   31           Private   45781       Masters             14
# 8   42           Private  159449     Bachelors             13
# 9   37           Private  280464  Some-college             10
#
#           marital_status         occupation   relationship   race     sex  \
# 0     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %% [markdown]
# <b> 2. Show me the average hours per week of all men who are working in private sector

# %%
pysqldf("SELECT Sex, Workclass, round(avg(hours_per_week),2) as Average_Hours FROM sqladb where workclass='Private' and sex='Male';")
# Out:
#     sex workclass  Average_Hours
# 0  Male   Private          42.22

# %% [markdown]
# <b> 3. Show me the frequency table for education, occupation and relationship, separately

# %%
pysqldf("SELECT education,COUNT(*) as frequency   FROM sqladb GROUP BY education ;")
# Out:
#        education  frequency
# 0           10th        933
# 1           11th       1175
# 2           12th        433
# 3        1st-4th        168
# 4        5th-6th        333
# 5        7th-8th        646
# 6            9th        514
# 7     Assoc-acdm       1067
# 8      Assoc-voc       1382
# 9      Bachelors       5354
# 10     Doctorate        413
# 11       HS-grad      10501
# 12       Masters       1723
# 13     Preschool         51
# 14   Prof-school        576
# 15  Some-college       7291

# %%
pysqldf("SELECT occupation,COUNT(*) as frequency  FROM sqladb GROUP BY occupation ;")
# Out:
#            occupation  frequency
# 0                   ?       1843
# 1        Adm-clerical       3769
# 2        Armed-Forces          9
# 3        Craft-repair       4099
# 4     Exec-managerial       4066
# 5     Farming-fishing        994
# 6   Handlers-cleaners       1370
# 7   Machine-op-inspct       2002
# 8       Other-service       3295
# 9     Priv-house-serv        149
# 10     Prof-specialty       4140
# 11    Protective-serv        649
# 12              Sales       3650
# 13       Tech-support        928
# 14   Transport-moving       1597

# %%
pysqldf("SELECT relationship,COUNT(*) as frequency FROM sqladb GROUP BY relationship ;")
# Out:
#      relationship  frequency
# 0         Husband      13193
# 1   Not-in-family       8304
# 2  Other-relative        981
# 3       Own-child       5068
# 4       Unmarried       3446
# 5            Wife       1568

# %% [markdown]
# <b> 4. Are there any people who are married, working in private sector and having a masters                degree

# %%
pysqldf("SELECT * FROM sqladb where Workclass='Private' and Education='Masters' and marital_status like ('Married%')")
# Out:
#      age workclass  fnlwgt education  education_num         marital_status  \
# 0     37   Private  284582   Masters             14     Married-civ-spouse
# 1     33   Private  202051   Masters             14     Married-civ-spouse
# 2     76   Private  124191   Masters             14     Married-civ-spouse
# 3     31   Private   99928   Masters             14     Married-civ-spouse
# 4     35   Private  138992   Masters             14     Married-civ-spouse
# 5     34   Private  142897   Masters             14     Married-civ-spouse
# 6     62   Private  270092   Masters             14     Married-civ-spouse
# 7     41   Private  445382   Masters             14     Married-civ-spouse
# 8     33   Private  208405   Masters             14     Married-civ-spouse
# 9     49   Private  192776   Masters             14     Married-civ-spouse
# 10    51   Private  410114   Masters             14     Married-civ-spouse
# ...

# %% [markdown]
# <b> 5. What is the average, minimum and maximum age group for people working in different               sectors

# %%
pysqldf("select Workclass, AVG(Age) as 'Average_Age',MIN(Age) as 'Min_Age',MAX(Age) as 'Max_Age' from sqladb group by Workclass")
# Out:
#           workclass  Average_Age  Min_Age  Max_Age
# 0                 ?    40.960240       17       90
# 1       Federal-gov    42.590625       17       90
# 2         Local-gov    41.751075       17       90
# 3      Never-worked    20.571429       17       30
# 4           Private    36.797585       17       90
# 5      Self-emp-inc    46.017025       17       84
# 6  Self-emp-not-inc    44.969697       17       90
# 7         State-gov    39.436392       17       81
# 8       Without-pay    47.785714       19       72

# %% [markdown]
# <b> 6. Calculate age distribution by country

# %%
pysqldf("""SELECT native_country as "country",
                age as "Age",
                COUNT(*) as 'Age_Distribution'
            FROM sqladb 
            GROUP BY native_country,age """)
# Out:
#          country  Age  Age_Distribution
# 0              ?   17                 2
# 1              ?   18                 8
# 2              ?   19                 5
# 3              ?   20                10
# 4              ?   21                11
# 5              ?   22                12
# 6              ?   23                 6
# 7              ?   24                14
# 8              ?   25                11
# 9              ?   26                18
# 10             ?   27                15
# 11             ?   28                19
# 12             ?   29                12
# 13             ?   30                19
# 14             ?   31                18
# 15             ?   32                17
# 16             ?   33                13
# 17             ?   34                24
# 18             ?   35                18
# 19             ?   36                23
# 20             ?   37                22
# 21             ?   38                20
# ...

# %% [markdown]
# <b> 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and 'capital-loss'

# %%
pysqldf(" select *, ((capital_gain)-(capital_loss) ) as Net_capital_Gain from sqladb;")
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       50  Self-emp-not-inc   83311     Bachelors             13
# 1       38           Private  215646       HS-grad              9
# 2       53           Private  234721          11th              7
# 3       28           Private  338409     Bachelors             13
# 4       37           Private  284582       Masters             14
# 5       49           Private  160187           9th              5
# 6       52  Self-emp-not-inc  209642       HS-grad              9
# 7       31           Private   45781       Masters             14
# 8       42           Private  159449     Bachelors             13
# 9       37           Private  280464  Some-college             10
# 10      30         State-gov  141297     Bachelors             13
# 11      23           Private  122272     Bachelors             13
# 12      32           Private  205019    Assoc-acdm             12
# ...

# %% [markdown]
# <b> Task 2:
#
# Read the following data set:
#
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

# %%
pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', sep=r'\s*,\s*',engine='python').head()
# Out:
#    39         State-gov   77516  Bachelors  13       Never-married  \
# 0  50  Self-emp-not-inc   83311  Bachelors  13  Married-civ-spouse
# 1  38           Private  215646    HS-grad   9            Divorced
# 2  53           Private  234721       11th   7  Married-civ-spouse
# 3  28           Private  338409  Bachelors  13  Married-civ-spouse
# 4  37           Private  284582    Masters  14  Married-civ-spouse
#
#         Adm-clerical  Not-in-family  White    Male  2174  0  40  \
# 0    Exec-managerial        Husband  White    Male     0  0  13
# 1  Handlers-cleaners  Not-in-family  White    Male     0  0  40
# 2  Handlers-cleaners        Husband  Black    Male     0  0  40
# 3     Prof-specialty           Wife  Black  Female     0  0  40
# 4    Exec-managerial           Wife  White  Female     0  0  40
#
#    United-States  <=50K
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3           Cuba  <=50K
# 4  United-States  <=50K

# %% [markdown]
# <b> 1.  Create an sqlalchemy engine using a sample from the data set

# %%
from sqlalchemy import create_engine

# %%
engine =create_engine('sqlite:///sqladb', echo=False) # Create sqlite engine
sqladb.to_sql('sqladb',con = engine,if_exists = 'replace') # Convert dataframe to sqlite object
con=sqlite3.connect('sqladb') #creating connection to sqldb
cur=con.cursor() # creating curser

# %% [markdown]
# <b> 2.  Write two basic update queries

# %%
sql = "update sqladb set education = 'UG' where education = 'Bachelors'" 
cur.execute(sql)
con.commit()
pd.read_sql_query("SELECT * FROM sqladb ", con).head()
# Out:
#    index  age         workclass  fnlwgt education  education_num  \
# 0      0   50  Self-emp-not-inc   83311        UG             13
# 1      1   38           Private  215646   HS-grad              9
# 2      2   53           Private  234721      11th              7
# 3      3   28           Private  338409        UG             13
# 4      4   37           Private  284582   Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# ...

# %%
sql = "update sqladb set marital_status = 'Unmarried' where marital_status = 'Never-married'" 
cur.execute(sql)
con.commit()
pd.read_sql_query("SELECT * FROM sqladb", con).head()
# Out:
#    index  age         workclass  fnlwgt education  education_num  \
# 0      0   50  Self-emp-not-inc   83311        UG             13
# 1      1   38           Private  215646   HS-grad              9
# 2      2   53           Private  234721      11th              7
# 3      3   28           Private  338409        UG             13
# 4      4   37           Private  284582   Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# ...

# %% [markdown]
# <b>3.  Write two delete queries

# %%
sql = "delete from sqladb where  Workclass ='?'" 
cur.execute(sql)
con.commit()
pd.read_sql_query("SELECT * FROM sqladb", con).head()
# Out:
#    index  age         workclass  fnlwgt education  education_num  \
# 0      0   50  Self-emp-not-inc   83311        UG             13
# 1      1   38           Private  215646   HS-grad              9
# 2      2   53           Private  234721      11th              7
# 3      3   28           Private  338409        UG             13
# 4      4   37           Private  284582   Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              13  United-States  <=50K
# ...

# %%
sql = "delete from sqladb where native_country in ('United-States','?')" 
cur.execute(sql)
con.commit()
pd.read_sql_query("SELECT * FROM sqladb", con).head()
# Out:
#    index  age  workclass  fnlwgt education  education_num  \
# 0      3   28    Private  338409        UG             13
# 1      5   49    Private  160187       9th              5
# 2     10   30  State-gov  141297        UG             13
# 3     14   34    Private  245487   7th-8th              4
# 4     34   48    Private  242406      11th              7
#
#           marital_status         occupation   relationship  \
# 0     Married-civ-spouse     Prof-specialty           Wife
# 1  Married-spouse-absent      Other-service  Not-in-family
# 2     Married-civ-spouse     Prof-specialty        Husband
# 3     Married-civ-spouse   Transport-moving        Husband
# 4              Unmarried  Machine-op-inspct      Unmarried
#
#                  race     sex  capital_gain  capital_loss  hours_per_week  \
# 0               Black  Female             0             0              40
# 1               Black  Female             0             0              16
# ...

# %% [markdown]
# <b> 4.  Write two filter queries

# %%
pd.read_sql_query("SELECT * FROM sqladb where relationship ='Not-in-family' and occupation in ('Handlers-cleaners','Adm-clerical') and income<>'<=50K' ", con)
# Out:
#    index  age         workclass  fnlwgt education  education_num  \
# 0   5384   61           Private  173924       9th              5
# 1   6589   77  Self-emp-not-inc   72931   7th-8th              4
# 2  15495   67           Private  224984   HS-grad              9
# 3  18082   38           Private  353263   Masters             14
#
#           marital_status         occupation   relationship   race     sex  \
# 0               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 1  Married-spouse-absent       Adm-clerical  Not-in-family  White    Male
# 2                Widowed       Adm-clerical  Not-in-family  White  Female
# 3              Unmarried       Adm-clerical  Not-in-family  White  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              40    Puerto-Rico   >50K
# 1             0             0              20          Italy   >50K
# ...

# %%
pd.read_sql_query("SELECT * FROM sqladb where workclass ='Private'  and Capital_Gain>0 ", con).head()
# Out:
#    index  age workclass  fnlwgt education  education_num      marital_status  \
# 0    310   34   Private  142897   Masters             14  Married-civ-spouse
# 1    592   31   Private  168387        UG             13  Married-civ-spouse
# 2   1367   52   Private  152234   HS-grad              9  Married-civ-spouse
# 3   1484   31   Private  209448      10th              6  Married-civ-spouse
# 4   1629   39   Private  328466      11th              7  Married-civ-spouse
#
#         occupation relationship                race   sex  capital_gain  \
# 0  Exec-managerial      Husband  Asian-Pac-Islander  Male          7298
# 1   Prof-specialty      Husband               White  Male          7688
# 2  Exec-managerial      Husband  Asian-Pac-Islander  Male         99999
# 3  Farming-fishing      Husband               White  Male          2105
# 4    Other-service      Husband               White  Male          2407
#
#    capital_loss  hours_per_week native_country income
# ...

# %% [markdown]
# <b> 5.  Write two function queries

# %%
def male_update(new_data):
    query_string = "update sqladb set Sex=? where Sex='Male'"
    cur.execute(query_string, new_data)
    #cursor.close()
    con.commit()
def female_update(new_data1):
    query_string = "update sqladb set Sex=? where Sex='Female'"
    cur.execute(query_string, new_data1)
    #cursor.close()
    con.commit()

male_update(['M'])
female_update(['F'])

pd.read_sql_query("SELECT * FROM sqladb", con).head()
# Out:
#    index  age  workclass  fnlwgt education  education_num  \
# 0      3   28    Private  338409        UG             13
# 1      5   49    Private  160187       9th              5
# 2     10   30  State-gov  141297        UG             13
# 3     14   34    Private  245487   7th-8th              4
# 4     34   48    Private  242406      11th              7
#
#           marital_status         occupation   relationship  \
# 0     Married-civ-spouse     Prof-specialty           Wife
# 1  Married-spouse-absent      Other-service  Not-in-family
# 2     Married-civ-spouse     Prof-specialty        Husband
# 3     Married-civ-spouse   Transport-moving        Husband
# 4              Unmarried  Machine-op-inspct      Unmarried
#
#                  race sex  capital_gain  capital_loss  hours_per_week  \
# 0               Black   F             0             0              40
# 1               Black   F             0             0              16
# ...

# %%
#2nd Query
def avg_age_population():
    con=sqlite3.connect('sqladb')
    cur=con.cursor()
    cur.execute("select education, Round(AVG(Age),2) as 'Average_Age' from sqladb group by education")
    res=cur.fetchall()
    con.close()
    return res

avg_age_population()
# Out:
# [('10th', 35.62),
#  ('11th', 31.12),
#  ('12th', 36.22),
#  ('1st-4th', 40.49),
#  ('5th-6th', 37.51),
#  ('7th-8th', 39.53),
#  ('9th', 34.57),
#  ('Assoc-acdm', 38.45),
#  ('Assoc-voc', 37.41),
#  ('Doctorate', 45.41),
#  ('HS-grad', 37.99),
#  ('Masters', 40.73),
#  ('Preschool', 40.9),
#  ('Prof-school', 41.78),
#  ('Some-college', 34.18),
#  ('UG', 39.63)]
